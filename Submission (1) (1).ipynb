# %% [markdown]
# # Section-2

# %% [markdown]
# # Importing modules

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Changing Directory

# %%
os.chdir(r'C:\Users\Domain\Desktop\PROJECT@HERO_VIRED')
os.listdir()
# Out:
# ['06 Org Profiling Case Study Data.xlsx',
#  '06 Org Profiling Case Study.pptx.pdf',
#  '~$06 Org Profiling Case Study Data.xlsx']

# %% [markdown]
# # Reading Data

# %%
df=pd.read_excel('06 Org Profiling Case Study Data.xlsx',sheet_name='Data')
df

# %%
df = pd.read_excel('casestudydata.xlsx')
df
# Out:
#                 Employee_Name  Salary  Terminated                  Position  \
# 0         Adinolfi, Wilson  K   62506           0   Production Technician I
# 1    Ait Sidi, Karthikeyan     104437           1                   Sr. DBA
# 2           Akinkuolie, Sarah   64955           1  Production Technician II
# 3                Alagbe,Trina   64991           0   Production Technician I
# 4            Anderson, Carol    50825           1   Production Technician I
# ..                        ...     ...         ...                       ...
# 306            Woodson, Jason   65893           0  Production Technician II
# 307        Ybarra, Catherine    48513           1   Production Technician I
# 308          Zamora, Jennifer  220450           0                       CIO
# 309               Zhou, Julia   89292           0              Data Analyst
# 310             Zima, Colleen   45046           0   Production Technician I
#
#            DOB Gender Marital_Status Hiring_Date Termination_Date  \
# 0   1983-10-07     M          Single  2011-05-07              NaT
# 1   1975-05-05     M         Married  2015-03-30       2016-06-16
# 2   1988-09-19      F        Married  2011-05-07       2012-09-24
# 3   1988-09-27      F        Married  2008-07-01              NaT
# 4   1989-08-09      F       Divorced  2011-11-07       2016-06-09
# ..         ...    ...            ...         ...              ...
# 306 1985-11-05     M          Single  2014-07-07              NaT
# 307 1982-04-05      F         Single  2008-02-09       2015-09-29
# 308 1979-08-30      F         Single  2010-10-04              NaT
# 309 1979-02-24      F         Single  2015-03-30              NaT
# 310 1978-08-17      F        Widowed  2014-09-29              NaT
#
#     Termination_Reason  ...    Manager_Name Manager_ID Recruitment_Source  \
# 0    N/A-StillEmployed  ...  Michael Albert       22.0           LinkedIn
# 1        career change  ...      Simon Roup        4.0             Indeed
# 2                hours  ...  Kissy Sullivan       20.0           LinkedIn
# 3    N/A-StillEmployed  ...    Elijiah Gray       16.0             Indeed
# 4     return to school  ...  Webster Butler       39.0      Google Search
# ..                 ...  ...             ...        ...                ...
# 306  N/A-StillEmployed  ...  Kissy Sullivan       20.0           LinkedIn
# 307   Another position  ...  Brannon Miller       12.0      Google Search
# 308  N/A-StillEmployed  ...      Janet King        2.0  Employee Referral
# 309  N/A-StillEmployed  ...      Simon Roup        4.0  Employee Referral
# 310  N/A-StillEmployed  ...   David Stanley       14.0           LinkedIn
#
#      Performance_Score Engagement_Survey Satisfaction_Score  Num_Spc_Projects  \
# 0              Exceeds              4.60                  5                 0
# 1          Fully Meets              4.96                  3                 6
# 2          Fully Meets              3.02                  3                 0
# 3          Fully Meets              4.84                  5                 0
# 4          Fully Meets              5.00                  4                 0
# ..                 ...               ...                ...               ...
# 306        Fully Meets              4.07                  4                 0
# 307                PIP              3.20                  2                 0
# 308            Exceeds              4.60                  5                 6
# 309        Fully Meets              5.00                  3                 5
# 310        Fully Meets              4.50                  5                 0
#
#      Last_Perf_Review_Date  Dayslate30 Num_Absences
# 0               2019-01-17           0            1
# 1               2016-02-24           0           17
# 2               2012-05-15           0            3
# 3               2019-03-01           0           15
# 4               2016-01-02           0            2
# ..                     ...         ...          ...
# 306             2019-02-28           0           13
# 307             2015-02-09           5            4
# 308             2019-02-21           0           16
# 309             2019-01-02           0           11
# 310             2019-01-30           0            2
#
# [311 rows x 22 columns]

# %% [markdown]
# # Variables are read in right form of Dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_Name          311 non-null    object
#  1   Salary                 311 non-null    int64
#  2   Terminated             311 non-null    int64
#  3   Position               311 non-null    object
#  4   DOB                    311 non-null    datetime64[ns]
#  5   Gender                 311 non-null    object
#  6   Marital_Status         311 non-null    object
#  7   Hiring_Date            311 non-null    datetime64[ns]
#  8   Termination_Date       104 non-null    datetime64[ns]
#  9   Termination_Reason     311 non-null    object
#  10  Curr_Emp_Status        311 non-null    object
#  11  Department             311 non-null    object
#  12  Manager_Name           311 non-null    object
#  13  Manager_ID             303 non-null    float64
#  14  Recruitment_Source     311 non-null    object
#  15  Performance_Score      311 non-null    object
#  16  Engagement_Survey      311 non-null    float64
#  17  Satisfaction_Score     311 non-null    int64
#  18  Num_Spc_Projects       311 non-null    int64
#  19  Last_Perf_Review_Date  311 non-null    datetime64[ns]
#  20  Dayslate30             311 non-null    int64
#  21  Num_Absences           311 non-null    int64
# dtypes: datetime64[ns](4), float64(2), int64(6), object(10)
# memory usage: 53.6+ KB

# %% [markdown]
# # Finding Number of Missing values in each column

# %%
df.isnull().sum()
# Out:
# Employee_Name              0
# Salary                     0
# Terminated                 0
# Position                   0
# DOB                        0
# Gender                     0
# Marital_Status             0
# Hiring_Date                0
# Termination_Date         207
# Termination_Reason         0
# Curr_Emp_Status            0
# Department                 0
# Manager_Name               0
# Manager_ID                 8
# Recruitment_Source         0
# Performance_Score          0
# Engagement_Survey          0
# Satisfaction_Score         0
# Num_Spc_Projects           0
# Last_Perf_Review_Date      0
# Dayslate30                 0
# Num_Absences               0
# dtype: int64

# %% [markdown]
# # Size of a dataframe

# %%
df.shape
# Out:
# (311, 22)

# %% [markdown]
# # Finding list of missing variables.

# %%
l=list(df.columns[df.isnull().any()])
l
# Out:
# ['Termination_Date', 'Manager_ID']

# %% [markdown]
#  # % missing_values

# %%
(df[l].isnull().sum()/df.shape[0]).round(2)
# Out:
# Termination_Date    0.67
# Manager_ID          0.03
# dtype: float64

# %% [markdown]
# # % Unique_values

# %%
for i in df.columns:
    print(i,'------',round((df[i].nunique()/df.shape[0])*100,3))
# Out:
# Employee_Name ------ 100.0
# Salary ------ 99.035
# Terminated ------ 0.643
# Position ------ 10.289
# DOB ------ 98.714
# Gender ------ 0.643
# Marital_Status ------ 1.608
# Hiring_Date ------ 32.476
# Termination_Date ------ 30.868
# Termination_Reason ------ 5.788
# Curr_Emp_Status ------ 0.965
# Department ------ 1.929
# Manager_Name ------ 6.752
# Manager_ID ------ 7.395
# Recruitment_Source ------ 2.894
# Performance_Score ------ 1.286
# Engagement_Survey ------ 38.264
# Satisfaction_Score ------ 1.608
# Num_Spc_Projects ------ 2.894
# Last_Perf_Review_Date ------ 44.051
# Dayslate30 ------ 2.251
# Num_Absences ------ 6.431

# %% [markdown]
# # Boxplots

# %%
# Outliers are present in the variable 'Salary'

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df,x='Salary');

# %%
# Description for above Boxplot
df['Salary'].describe()
# Out:
# count       311.000000
# mean      69020.684887
# std       25156.636930
# min       45046.000000
# 25%       55501.500000
# 50%       62810.000000
# 75%       72036.000000
# max      250000.000000
# Name: Salary, dtype: float64

# %%
# Outliers are there for variable 'Engagement_Survey'
sns.boxplot(data=df,x='Engagement_Survey');

# %%
#Description for above Boxplot
df['Engagement_Survey'].describe()
# Out:
# count    311.000000
# mean       4.110000
# std        0.789938
# min        1.120000
# 25%        3.690000
# 50%        4.280000
# 75%        4.700000
# max        5.000000
# Name: Engagement_Survey, dtype: float64

# %% [markdown]
# # Finding number of Duplicate records

# %%
df.duplicated().sum() #No duplicate values present in the given data.
# Out:
# 0

# %% [markdown]
# # Generating Extended  Data Dictionary

# %% [markdown]
# ## Overall Summary of Numeric variables

# %%
temp=(df.describe(percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99]).T).round(2)
temp
# Out:
#                     count      mean       std       min        1%       5%  \
# Salary              311.0  69020.68  25156.64  45046.00  45398.80  46999.5
# Terminated          311.0      0.33      0.47      0.00      0.00      0.0
# Manager_ID          303.0     14.57      8.08      1.00      1.00      2.0
# Engagement_Survey   311.0      4.11      0.79      1.12      1.82      2.4
# Satisfaction_Score  311.0      3.89      0.91      1.00      2.00      3.0
# Num_Spc_Projects    311.0      1.22      2.35      0.00      0.00      0.0
# Dayslate30          311.0      0.41      1.29      0.00      0.00      0.0
# Num_Absences        311.0     10.24      5.85      1.00      1.00      2.0
#
#                          25%       50%      75%       95%       99%       max
# Salary              55501.50  62810.00  72036.0  108106.5  177250.0  250000.0
# Terminated              0.00      0.00      1.0       1.0       1.0       1.0
# Manager_ID             10.00     15.00     19.0      22.0      39.0      39.0
# Engagement_Survey       3.69      4.28      4.7       5.0       5.0       5.0
# Satisfaction_Score      3.00      4.00      5.0       5.0       5.0       5.0
# Num_Spc_Projects        0.00      0.00      0.0       6.0       7.0       8.0
# Dayslate30              0.00      0.00      0.0       4.0       6.0       6.0
# Num_Absences            5.00     10.00     15.0      19.0      20.0      20.0

# %% [markdown]
# ## Overall summary of Object varables

# %%
df.describe(include='object').T
# Out:
#                    count unique                      top freq
# Employee_Name        311    311             True, Edward    1
# Position             311     32  Production Technician I  137
# Gender               311      2                        F  176
# Marital_Status       311      5                   Single  137
# Termination_Reason   311     18        N/A-StillEmployed  207
# Curr_Emp_Status      311      3                   Active  207
# Department           311      6        Production         209
# Manager_Name         311     21           Michael Albert   22
# Recruitment_Source   311      9                   Indeed   87
# Performance_Score    311      4              Fully Meets  243

# %% [markdown]
# ## Overall summary of all the Variables

# %%
df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# Out:
# <ipython-input-149-ca85a32e6b3c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# <ipython-input-149-ca85a32e6b3c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# <ipython-input-149-ca85a32e6b3c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
# <ipython-input-149-ca85a32e6b3c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.5,0.95,0.99]).T
#                        count unique                      top freq      first  \
# Employee_Name            311    311             True, Edward    1        NaT
# Salary                 311.0    NaN                      NaN  NaN        NaT
# Terminated             311.0    NaN                      NaN  NaN        NaT
# Position                 311     32  Production Technician I  137        NaT
# DOB                      311    307      1984-07-07 00:00:00    2 1951-02-01
# Gender                   311      2                        F  176        NaT
# Marital_Status           311      5                   Single  137        NaT
# Hiring_Date              311    101      2011-10-01 00:00:00   14 2006-09-01
# Termination_Date         104     96      2018-08-19 00:00:00    2 2010-08-30
# Termination_Reason       311     18        N/A-StillEmployed  207        NaT
# Curr_Emp_Status          311      3                   Active  207        NaT
# Department               311      6        Production         209        NaT
# Manager_Name             311     21           Michael Albert   22        NaT
# Manager_ID             303.0    NaN                      NaN  NaN        NaT
# Recruitment_Source       311      9                   Indeed   87        NaT
# Performance_Score        311      4              Fully Meets  243        NaT
# Engagement_Survey      311.0    NaN                      NaN  NaN        NaT
# Satisfaction_Score     311.0    NaN                      NaN  NaN        NaT
# Num_Spc_Projects       311.0    NaN                      NaN  NaN        NaT
# Last_Perf_Review_Date    311    137      2019-01-14 00:00:00   18 2010-07-14
# Dayslate30             311.0    NaN                      NaN  NaN        NaT
# Num_Absences           311.0    NaN                      NaN  NaN        NaT
#
#                             last          mean          std      min       1%  \
# Employee_Name                NaT           NaN          NaN      NaN      NaN
# Salary                       NaT  69020.684887  25156.63693  45046.0  45398.8
# Terminated                   NaT      0.334405     0.472542      0.0      0.0
# Position                     NaT           NaN          NaN      NaN      NaN
# DOB                   1992-08-17           NaN          NaN      NaN      NaN
# Gender                       NaT           NaN          NaN      NaN      NaN
# Marital_Status               NaT           NaN          NaN      NaN      NaN
# Hiring_Date           2018-09-07           NaN          NaN      NaN      NaN
# Termination_Date      2018-10-11           NaN          NaN      NaN      NaN
# Termination_Reason           NaT           NaN          NaN      NaN      NaN
# Curr_Emp_Status              NaT           NaN          NaN      NaN      NaN
# Department                   NaT           NaN          NaN      NaN      NaN
# Manager_Name                 NaT           NaN          NaN      NaN      NaN
# Manager_ID                   NaT     14.570957     8.078306      1.0      1.0
# Recruitment_Source           NaT           NaN          NaN      NaN      NaN
# Performance_Score            NaT           NaN          NaN      NaN      NaN
# Engagement_Survey            NaT          4.11     0.789938     1.12    1.822
# Satisfaction_Score           NaT      3.890675     0.909241      1.0      2.0
# Num_Spc_Projects             NaT       1.21865     2.349421      0.0      0.0
# Last_Perf_Review_Date 2019-12-02           NaN          NaN      NaN      NaN
# Dayslate30                   NaT      0.414791     1.294519      0.0      0.0
# Num_Absences                 NaT     10.237942     5.852596      1.0      1.0
#
#                            50%       95%       99%       max
# Employee_Name              NaN       NaN       NaN       NaN
# Salary                 62810.0  108106.5  177250.0  250000.0
# Terminated                 0.0       1.0       1.0       1.0
# Position                   NaN       NaN       NaN       NaN
# DOB                        NaN       NaN       NaN       NaN
# Gender                     NaN       NaN       NaN       NaN
# Marital_Status             NaN       NaN       NaN       NaN
# Hiring_Date                NaN       NaN       NaN       NaN
# Termination_Date           NaN       NaN       NaN       NaN
# Termination_Reason         NaN       NaN       NaN       NaN
# Curr_Emp_Status            NaN       NaN       NaN       NaN
# Department                 NaN       NaN       NaN       NaN
# Manager_Name               NaN       NaN       NaN       NaN
# Manager_ID                15.0      22.0      39.0      39.0
# Recruitment_Source         NaN       NaN       NaN       NaN
# Performance_Score          NaN       NaN       NaN       NaN
# Engagement_Survey         4.28       5.0       5.0       5.0
# Satisfaction_Score         4.0       5.0       5.0       5.0
# Num_Spc_Projects           0.0       6.0       7.0       8.0
# Last_Perf_Review_Date      NaN       NaN       NaN       NaN
# Dayslate30                 0.0       4.0       6.0       6.0
# Num_Absences              10.0      19.0      20.0      20.0

# %%
### Obsevations:
### From Numeric Variables:
#✔Average Salary of the employees in the company is around 69000.
#✔The mean percentage of terminated employees is 33%.
#✔Average value of the Engagement_Survey is around 4.11.
#✔Mean value of Satisfaction_Score is around 3.89.
#✔Average number of Absences is around 10 days.
### From Categorical variables:
#✔There are more number of employees working in the position of Production Technician I.
#✔Most of the employees are working in the Production Department.
#✔Most of the freshers are recruited through the source:Indeed.

# %% [markdown]
# # Section-3

# %% [markdown]
# ## Univariate Analysis of Object variables

# %%
plt.figure(figsize=(80,10))
sns.countplot(data=df,x='Position');

# %%
### Obsevations
#From the above countplot, we can say that there more number of employees are working as 
#Production_Technicians in the given data.

# %%
plt.figure(figsize=(80,10))
sns.countplot(data=df,x='Termination_Reason');

# %%
n_df=df[df['Termination_Reason'].isin(['Another position','unhappy','more money','career change''hours'] )] 
n_df
# Out:
#             Employee_Name  Salary  Terminated                  Position  \
# 10   Baczenski, Rachael     54670           1   Production Technician I
# 11        Barbara, Thomas   47211           1   Production Technician I
# 14          Barton, Nader   52505           1   Production Technician I
# 28           Brill, Donna   53492           1   Production Technician I
# 32       Bunbury, Jessica   74326           1        Area Sales Manager
# 49    Cloninger, Jennifer   64066           1  Production Technician II
# 65        DeGweck,  James   55722           1   Production Technician I
# 68          Demita, Carla   58275           1  Production Technician II
# 119          Gross, Paula   63813           1   Production Technician I
# 136           Huynh, Ming   68182           1  Production Technician II
# 137     Immediato, Walter   83082           1        Production Manager
# 143       Johnson, George   46837           1   Production Technician I
# 146          Jung, Judy     61154           1   Production Technician I
# 151  Kinsella, Kathleen     54005           1   Production Technician I
# 152   Kirill, Alexandra     45433           1   Production Technician I
# 158     Langford, Lindsey   66074           1  Production Technician II
# 161       Latif, Mohammed   61962           1  Production Technician II
# 168     Linares, Marilyn    52624           1   Production Technician I
# 171          Lundy, Susan   67237           1  Production Technician II
# 174        Lynch, Lindsay   47434           1   Production Technician I
# 178        Mancuso, Karen   68407           1  Production Technician II
# 185      Meads, Elizabeth   62659           1   Production Technician I
# 188           Miller, Ned   55800           1  Production Technician II
# 199           Ndzi, Horia   46664           1   Production Technician I
# 206       Oliver, Brooke    71966           1  Production Technician II
# 211        Panjwani, Nina   63515           1   Production Technician I
# 212      Patronick, Lucas  108987           1         Software Engineer
# 215     Pelletier, Ermine   60270           1  Production Technician II
# 217        Peters, Lauren   57954           1  Production Technician II
# 218    Peterson, Ebonee     74669           1        Production Manager
# 221            Pham, Hong   64724           1   Production Technician I
# 224        Power, Morissa   46799           1   Production Technician I
# 226      Purinton, Janine   46430           1   Production Technician I
# 229        Rarrick, Quinn   61729           1   Production Technician I
# 234      Robertson, Peter   55578           1  Production Technician II
# 239      Roehrich, Bianca  120000           1  Principal Data Architect
# 242       Rossetti, Bruno   53180           1   Production Technician I
# 265    Squatrito, Kristen   62425           1   Production Technician I
# 276    Tavares, Desiree     60754           1   Production Technician I
# 277       Tejeda, Lenora    72202           1  Production Technician II
# 286       Trzeciak, Cybil   74813           1  Production Technician II
# 296  Wallace, Courtney  E   80512           1        Production Manager
# 301         Wilber, Barry   55140           1   Production Technician I
# 302         Wilkes, Annie   58062           1   Production Technician I
# 307    Ybarra, Catherine    48513           1   Production Technician I
#
#            DOB Gender Marital_Status Hiring_Date Termination_Date  \
# 10  1974-12-01      F        Married  2011-10-01       2017-12-01
# 11  1974-02-21     M         Married  2012-02-04       2016-09-19
# 14  1977-07-15     M        Divorced  2012-09-24       2017-06-04
# 28  1990-08-24      F        Married  2012-02-04       2013-06-15
# 32  1964-01-06      F        Married  2011-08-15       2014-02-08
# 49  1981-08-31      F        Married  2011-05-16       2013-07-01
# 65  1977-10-31     M         Married  2011-05-16       2016-08-06
# 68  1951-02-25      F      Separated  2011-04-04       2015-04-11
# 119 1983-05-21      F       Divorced  2011-02-21       2014-11-01
# 136 1976-09-22      F       Divorced  2011-02-21       2013-01-04
# 137 1976-11-15     M         Married  2011-02-21       2012-09-24
# 143 1959-08-19     M         Married  2011-07-11       2018-04-29
# 146 1986-04-17      F        Married  2011-10-01       2016-01-04
# 151 1973-08-12      F        Married  2011-09-26       2015-04-06
# 152 1970-08-10      F        Married  2011-09-26       2014-09-01
# 158 1979-07-25      F       Divorced  2013-07-01       2014-03-31
# 161 1984-09-05     M         Married  2012-02-04       2013-04-15
# 168 1981-03-26      F        Married  2011-05-07       2018-09-26
# 171 1976-12-26      F        Widowed  2013-08-07       2016-09-15
# 174 1973-02-14      F         Single  2011-07-11       2015-11-14
# 178 1986-10-12      F        Married  2011-05-07       2012-08-19
# 185 1968-05-30      F         Single  2012-02-04       2016-11-11
# 188 1985-06-29     M          Single  2011-08-15       2014-04-09
# 199 1983-03-28     M         Married  2013-01-04       2016-05-25
# 206 1952-11-02      F        Married  2012-05-14       2013-08-19
# 211 1979-01-05      F        Married  2011-07-02       2014-12-01
# 212 1979-02-20     M          Single  2011-07-11       2015-07-09
# 215 1989-07-18      F        Married  2011-05-07       2015-09-15
# 217 1986-08-17      F        Married  2011-05-16       2013-04-02
# 218 1977-09-05      F        Married  2010-10-25       2016-05-18
# 221 1988-06-03     M         Married  2011-05-07       2012-11-30
# 224 1984-10-15      F       Divorced  2011-05-16       2018-04-06
# 226 1970-09-22      F       Divorced  2012-09-24       2013-06-18
# 229 1984-12-31     M        Divorced  2011-09-26       2018-07-04
# 234 1972-03-07     M         Married  2011-05-07       2012-08-02
# 239 1973-05-27      F         Single  2015-05-01       2018-10-11
# 242 1987-03-18     M          Single  2011-04-04       2018-08-13
# 265 1973-03-26      F       Divorced  2013-05-13       2015-06-29
# 276 1975-03-04      F        Married  2009-04-27       2013-01-04
# 277 1953-05-24      F        Married  2011-05-16       2017-08-07
# 286 1985-03-15      F         Single  2011-10-01       2014-02-07
# 296 1955-11-14      F        Married  2011-09-26       2012-02-01
# 301 1965-09-09     M         Married  2011-05-16       2015-07-09
# 302 1983-07-30      F       Divorced  2011-10-01       2012-05-14
# 307 1982-04-05      F         Single  2008-02-09       2015-09-29
#
#     Termination_Reason  ...     Manager_Name Manager_ID  \
# 10    Another position  ...    David Stanley       14.0
# 11             unhappy  ...   Kissy Sullivan       20.0
# 14    Another position  ...   Michael Albert       22.0
# 28    Another position  ...    David Stanley       14.0
# 32    Another position  ...       John Smith       17.0
# 49             unhappy  ...   Brannon Miller       12.0
# 65             unhappy  ...   Webster Butler       39.0
# 68          more money  ...    Kelley Spirea       18.0
# 119         more money  ...    Kelley Spirea       18.0
# 136            unhappy  ...         Amy Dunn       11.0
# 137            unhappy  ...       Janet King        2.0
# 143         more money  ...   Michael Albert       22.0
# 146            unhappy  ...     Elijiah Gray       16.0
# 151         more money  ...   Webster Butler       39.0
# 152         more money  ...         Amy Dunn       11.0
# 158   Another position  ...    David Stanley       14.0
# 161         more money  ...   Kissy Sullivan       20.0
# 168            unhappy  ...   Michael Albert       22.0
# 171         more money  ...   Michael Albert       22.0
# 174   Another position  ...   Webster Butler       39.0
# 178   Another position  ...         Amy Dunn       11.0
# 185   Another position  ...    Kelley Spirea       18.0
# 188            unhappy  ...   Brannon Miller       12.0
# 199         more money  ...         Amy Dunn       11.0
# 206            unhappy  ...   Webster Butler       39.0
# 211   Another position  ...     Elijiah Gray       16.0
# 212   Another position  ...  Alex Sweetwater       10.0
# 215            unhappy  ...         Amy Dunn       11.0
# 217         more money  ...    Ketsia Liebig       19.0
# 218   Another position  ...       Janet King        2.0
# 221         more money  ...   Brannon Miller       12.0
# 224   Another position  ...   Kissy Sullivan       20.0
# 226            unhappy  ...   Kissy Sullivan       20.0
# 229         more money  ...   Michael Albert       22.0
# 234   Another position  ...   Kissy Sullivan       20.0
# 239   Another position  ...       Simon Roup        4.0
# 242   Another position  ...   Kissy Sullivan       20.0
# 265            unhappy  ...    David Stanley       14.0
# 276   Another position  ...   Webster Butler       39.0
# 277   Another position  ...     Elijiah Gray       16.0
# 286            unhappy  ...         Amy Dunn       11.0
# 296   Another position  ...       Janet King        2.0
# 301            unhappy  ...         Amy Dunn       11.0
# 302   Another position  ...    Ketsia Liebig       19.0
# 307   Another position  ...   Brannon Miller       12.0
#
#           Recruitment_Source  Performance_Score Engagement_Survey  \
# 10        Diversity Job Fair        Fully Meets              4.20
# 11        Diversity Job Fair        Fully Meets              4.20
# 14   On-line Web application        Fully Meets              5.00
# 28             Google Search        Fully Meets              3.35
# 32             Google Search        Fully Meets              3.14
# 49             Google Search        Fully Meets              4.20
# 65                    Indeed        Fully Meets              5.00
# 68             Google Search        Fully Meets              4.62
# 119            CareerBuilder        Fully Meets              5.00
# 136            Google Search        Fully Meets              3.72
# 137                   Indeed  Needs Improvement              2.34
# 143            CareerBuilder            Exceeds              4.70
# 146            CareerBuilder        Fully Meets              4.00
# 151            Google Search        Fully Meets              3.60
# 152            Google Search        Fully Meets              3.49
# 158                   Indeed        Fully Meets              4.52
# 161            Google Search        Fully Meets              4.90
# 168                   Indeed        Fully Meets              3.18
# 171                 LinkedIn        Fully Meets              4.65
# 174       Diversity Job Fair            Exceeds              5.00
# 178                 LinkedIn        Fully Meets              5.00
# 185       Diversity Job Fair        Fully Meets              4.18
# 188                 LinkedIn                PIP              3.00
# 199        Employee Referral        Fully Meets              3.18
# 206                 LinkedIn        Fully Meets              5.00
# 211            Google Search        Fully Meets              3.89
# 212       Diversity Job Fair            Exceeds              5.00
# 215            CareerBuilder  Needs Improvement              2.40
# 217                   Indeed            Exceeds              4.20
# 218                   Indeed        Fully Meets              4.16
# 221            Google Search        Fully Meets              5.00
# 224            Google Search        Fully Meets              3.17
# 226                   Indeed        Fully Meets              4.50
# 229                   Indeed        Fully Meets              3.80
# 234                   Indeed        Fully Meets              4.20
# 239                 LinkedIn        Fully Meets              3.88
# 242            Google Search        Fully Meets              5.00
# 265                 LinkedIn            Exceeds              4.10
# 276       Diversity Job Fair        Fully Meets              4.50
# 277            Google Search        Fully Meets              3.93
# 286                 LinkedIn        Fully Meets              4.40
# 296       Diversity Job Fair        Fully Meets              4.50
# 301                  Website        Fully Meets              5.00
# 302            Google Search        Fully Meets              3.60
# 307            Google Search                PIP              3.20
#
#     Satisfaction_Score  Num_Spc_Projects  Last_Perf_Review_Date  Dayslate30  \
# 10                   4                 0             2016-01-30           0
# 11                   3                 0             2016-06-05           0
# 14                   5                 0             2017-02-03           0
# 28                   4                 0             2013-04-03           0
# 32                   5                 0             2013-10-02           1
# 49                   5                 0             2012-03-05           0
# 65                   4                 0             2016-02-04           0
# 68                   5                 0             2015-06-05           0
# 119                  5                 0             2013-03-06           0
# 136                  3                 0             2013-01-02           0
# 137                  2                 0             2012-12-04           3
# 143                  4                 0             2018-02-14           0
# 146                  4                 0             2016-03-02           0
# 151                  5                 0             2015-01-03           0
# 152                  4                 0             2013-01-30           0
# 158                  3                 0             2014-02-20           0
# 161                  3                 0             2013-02-20           0
# 168                  4                 0             2018-02-03           0
# 171                  4                 0             2016-10-06           0
# 174                  4                 0             2015-02-02           0
# 178                  4                 0             2012-02-07           0
# 185                  4                 0             2016-05-02           0
# 188                  2                 0             2013-01-14           6
# 199                  3                 0             2016-06-03           0
# 206                  3                 0             2013-02-07           0
# 211                  4                 0             2013-04-03           0
# 212                  5                 3             2015-08-16           0
# 215                  5                 0             2015-06-02           5
# 217                  5                 0             2013-10-01           0
# 218                  5                 0             2015-05-03           0
# 221                  3                 0             2012-02-20           0
# 224                  4                 0             2018-02-04           0
# 226                  5                 0             2013-02-04           0
# 229                  5                 0             2018-04-02           0
# 234                  5                 0             2012-06-01           0
# 239                  3                 7             2018-02-13           0
# 242                  5                 0             2018-02-07           0
# 265                  4                 0             2015-02-03           0
# 276                  5                 0             2012-02-15           0
# 277                  3                 0             2017-04-18           0
# 286                  3                 0             2014-05-01           0
# 296                  3                 0             2012-02-01           0
# 301                  3                 0             2015-02-15           0
# 302                  5                 0             2011-06-02           0
# 307                  2                 0             2015-02-09           5
#
#     Num_Absences
# 10            12
# 11            15
# 14             1
# 28             6
# 32            19
# 49             9
# 65            14
# 68             1
# 119           17
# 136           18
# 137            4
# 143            9
# 146            4
# 151           16
# 152            6
# 158           20
# 161           20
# 168           16
# 171           15
# 174           17
# 178           16
# 185           17
# 188            6
# 199           10
# 206           17
# 211            7
# 212           13
# 215            2
# 217           12
# 218            6
# 221           13
# 224           14
# 226           16
# 229           19
# 234           13
# 239           12
# 242            4
# 265           16
# 276           11
# 277            3
# 286            5
# 296            5
# 301            7
# 302            9
# 307            4
#
# [45 rows x 22 columns]

# %%
k=n_df['Termination_Reason'].value_counts(normalize=True)
k
# Out:
# Another position    0.444444
# unhappy             0.311111
# more money          0.244444
# Name: Termination_Reason, dtype: float64

# %%
plt.pie(k,labels=['Another position', 'unhappy', 'more money', 'career change', 'hours'],autopct='%1.2f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-17d1c82d8afc> in <module>
# ----> 1 plt.pie(k,labels=['Another position', 'unhappy', 'more money', 'career change', 'hours'],autopct='%1.2f%%')
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3022             explode = [0] * len(x)
#    3023         if len(x) != len(labels):
# -> 3024             raise ValueError("'label' must be of length 'x'")
#    3025         if len(x) != len(explode):
#    3026             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
### Observations:
#✔Most of the  employees are terinated since they are shifting to another position.

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='Curr_Emp_Status');

# %%
k=df['Curr_Emp_Status'].value_counts(normalize=True)
k
# Out:
# Active                    0.665595
# Voluntarily Terminated    0.282958
# Terminated for Cause      0.051447
# Name: Curr_Emp_Status, dtype: float64

# %%
plt.pie(k,labels=['Active','Voluntarily Terminated','Terminated for Cause'],autopct='%1.2f%%')
plt.show()

# %%
### Observations:
#✔ Almost 66% of total employess are currently working in the Company.
#✔ Nearly 28% of total employees are voluntarily terminated from the company.
#✔ nearly 5% of employees are terminated from the company due to some cause.

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='Department');

# %%
k=df['Department'].value_counts(normalize=True)
k
# Out:
# Production              0.672026
# IT/IS                   0.160772
# Sales                   0.099678
# Software Engineering    0.035370
# Admin Offices           0.028939
# Executive Office        0.003215
# Name: Department, dtype: float64

# %%
plt.pie(k,labels=['Production', 'IT/IS','Sales','Software Engineering','Admin Offices','Executive Office'],autopct='%1.2f%%')
plt.show()
# Out:
# <ipython-input-169-4805c1f2f846>:1: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(k,labels=['Production', 'IT/IS','Sales','Software Engineering','Admin Offices','Executive Office'],autopct='%1.2f%%')

# %%
### Observations
#✔Almost 67% of the  employees are from  the Production department.

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df,x='Recruitment_Source');

# %%
k=df['Recruitment_Source'].value_counts(normalize=True)
print(list(k.index))
# Out:
# ['Indeed', 'LinkedIn', 'Google Search', 'Employee Referral', 'Diversity Job Fair', 'CareerBuilder', 'Website', 'Other', 'On-line Web application']

# %%
plt.pie(k,labels=['Indeed', 'LinkedIn', 'Google Search', 'Employee Referral', 'Diversity Job Fair', 'CareerBuilder', 'Website', 'Other', 'On-line Web application'],autopct='%1.2f%%')
plt.show()

# %%
### Obseravtions
#✔ Most of the freshers are came to know about the Job recruitment source Indeed and Linked-in social media plattforms.

# %%
sns.countplot(data=df,x='Performance_Score');

# %%
k=df['Performance_Score'].value_counts(normalize=True)
k
# Out:
# Fully Meets          0.781350
# Exceeds              0.118971
# Needs Improvement    0.057878
# PIP                  0.041801
# Name: Performance_Score, dtype: float64

# %%
plt.pie(k,labels=['Fully Meets','Exceeds','Needs Improvement','PIP'])
plt.show()

# %%
### Observations:
#✔ Almost 78% of employees performance is Fully meets.

# %% [markdown]
# ## Univariate Analysis of Numeric Vriables

# %%
sns.histplot(df['Terminated'],edgecolor='black')
plt.show()

# %%
df['Terminated'].value_counts(normalize=True)
# Out:
# 0    0.665595
# 1    0.334405
# Name: Terminated, dtype: float64

# %%
### Obsevations:
#✔ Almost 33% of employees are being Terminated from the company.

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['Salary'],edgecolor='black')
plt.show()

# %%
### Observations:
#✔ There are more number of employees are having low salary.
#✔ There are few employees in the company with very high salary.

# %%
sns.histplot(df['Engagement_Survey'],edgecolor='black')
plt.show()

# %%
df['Engagement_Survey'].value_counts(normalize=True)
# Out:
# 5.00    0.180064
# 4.50    0.061093
# 4.30    0.054662
# 4.20    0.054662
# 4.10    0.051447
#           ...
# 2.60    0.003215
# 4.94    0.003215
# 3.11    0.003215
# 3.51    0.003215
# 3.08    0.003215
# Name: Engagement_Survey, Length: 119, dtype: float64

# %%
### Observations:
#✔ Almost 18% of employees who are engaging more  in the given work.

# %%
sns.histplot(df['Satisfaction_Score'],edgecolor='black')
plt.show()

# %%
df['Satisfaction_Score'].value_counts(normalize=True)
# Out:
# 3    0.347267
# 5    0.315113
# 4    0.302251
# 2    0.028939
# 1    0.006431
# Name: Satisfaction_Score, dtype: float64

# %%
### Observations:
#✔ Almost  34% of the employees had given satisfaction score 3.0---indicates  employees not satisfied with company policies.

# %%
sns.histplot(df['Num_Spc_Projects'],edgecolor='black')
plt.show()

# %%
df['Num_Spc_Projects'].value_counts(normalize=True)
# Out:
# 0    0.774920
# 5    0.067524
# 6    0.067524
# 7    0.038585
# 4    0.028939
# 3    0.009646
# 8    0.006431
# 1    0.003215
# 2    0.003215
# Name: Num_Spc_Projects, dtype: float64

# %%
### Observations
#✔ Almost 77% of employees had not done any special projects--company should make a  note of it.

# %%
sns.histplot(df['Dayslate30'],edgecolor='black')
plt.show()

# %%
df['Dayslate30'].value_counts(normalize=True)
# Out:
# 0    0.893891
# 4    0.025723
# 2    0.019293
# 3    0.019293
# 5    0.019293
# 6    0.019293
# 1    0.003215
# Name: Dayslate30, dtype: float64

# %%
### Observations:
#✔ This indicates 89% of employees are coming in time to work in the last 30 days.

# %%
sns.histplot(df['Num_Absences'],edgecolor='black')
plt.show()

# %%
df['Num_Absences'].value_counts(normalize=True)
# Out:
# 4     0.073955
# 16    0.073955
# 7     0.067524
# 2     0.067524
# 15    0.064309
# 13    0.054662
# 14    0.054662
# 3     0.051447
# 19    0.051447
# 6     0.051447
# 11    0.048232
# 17    0.048232
# 1     0.045016
# 9     0.045016
# 20    0.045016
# 5     0.038585
# 8     0.035370
# 10    0.032154
# 12    0.025723
# 18    0.025723
# Name: Num_Absences, dtype: float64

# %%
### Observations
#✔There are many employees in the which are very irregualar to the Company--which are not required for the company.

# %% [markdown]
# # Bivariate Variations

# %%
  pd.crosstab(df['Department'],df['Terminated'])
# Out:
# Terminated              0   1
# Department
# Admin Offices           7   2
# Executive Office        1   0
# IT/IS                  40  10
# Production            126  83
# Sales                  26   5
# Software Engineering    7   4

# %%
# From this we can say that there are more number of vacancies present in the company in Production department. 
plt.figure(figsize=(18,7))
sns.countplot(data=df,x='Department',hue='Terminated');

# %%
### Observations
#✔ From this we can know about status of current working employees  and terminated employees in certain department.
#✔ From this we can say that there are more number of vacancies present in the company in Production department.

# %%
pd.crosstab(df['Department'],df['Termination_Reason'])
# Out:
# Termination_Reason    Another position  Fatal attraction  \
# Department
# Admin Offices                        0                 0
# Executive Office                     0                 0
# IT/IS                                1                 0
# Production                          17                 0
# Sales                                1                 1
# Software Engineering                 1                 0
#
# Termination_Reason    Learned that he is a gangster  N/A-StillEmployed  \
# Department
# Admin Offices                                     0                  7
# Executive Office                                  0                  1
# IT/IS                                             1                 40
# Production                                        0                126
# Sales                                             0                 26
# Software Engineering                              0                  7
#
# Termination_Reason    attendance  career change  gross misconduct  hours  \
# Department
# Admin Offices                  0              1                 0      0
# Executive Office               0              0                 0      0
# IT/IS                          0              1                 0      2
# Production                     5              6                 1      6
# Sales                          1              0                 0      0
# Software Engineering           1              1                 0      0
#
# Termination_Reason    maternity leave - did not return  medical issues  \
# Department
# Admin Offices                                        0               0
# Executive Office                                     0               0
# IT/IS                                                0               1
# Production                                           2               1
# Sales                                                1               0
# Software Engineering                                 0               1
#
# Termination_Reason    military  more money  no-call, no-show  performance  \
# Department
# Admin Offices                0           0                 1            0
# Executive Office             0           0                 0            0
# IT/IS                        0           0                 2            2
# Production                   4          11                 1            2
# Sales                        0           0                 0            0
# Software Engineering         0           0                 0            0
#
# Termination_Reason    relocation out of area  retiring  return to school  \
# Department
# Admin Offices                              0         0                 0
# Executive Office                           0         0                 0
# IT/IS                                      0         0                 0
# Production                                 4         4                 5
# Sales                                      1         0                 0
# Software Engineering                       0         0                 0
#
# Termination_Reason    unhappy
# Department
# Admin Offices               0
# Executive Office            0
# IT/IS                       0
# Production                 14
# Sales                       0
# Software Engineering        0

# %%
### Observations
#✔ We can  know  about the count of Terminations department_wise. 
#✔ Many of the persons from the Production Department are terminated due to shifting to Another position.

# %%
# Dissatisfaction of employees in company's policies.
pd.crosstab(df['Termination_Reason'],df['Satisfaction_Score'])
# Out:
# Satisfaction_Score                1  2   3   4   5
# Termination_Reason
# Another position                  0  1   4   7   8
# Fatal attraction                  0  0   0   0   1
# Learned that he is a gangster     0  0   0   0   1
# N/A-StillEmployed                 2  5  75  56  69
# attendance                        0  0   2   4   1
# career change                     0  0   4   3   2
# gross misconduct                  0  0   0   0   1
# hours                             0  0   3   3   2
# maternity leave - did not return  0  0   0   1   2
# medical issues                    0  0   2   1   0
# military                          0  0   2   2   0
# more money                        0  0   3   3   5
# no-call, no-show                  0  0   3   1   0
# performance                       0  1   1   2   0
# relocation out of area            0  0   0   2   3
# retiring                          0  0   2   2   0
# return to school                  0  0   2   3   0
# unhappy                           0  2   5   4   3

# %%
plt.figure(figsize=(40,10))
sns.countplot(data=df,x='Termination_Reason',hue='Satisfaction_Score');
plt.xlabel('Termination_Reason')
plt.show()

# %%
### Obsevations:
#✔ Many of current employees are have given low score due to some inconvenience in the company.
#✔ Improving Comapny policies will help the company from the termination of current employees.

# %%
sns.set_theme()

# %%
plt.figure(figsize=(50,10))
sns.countplot(data=df,x='Department',hue='Num_Absences');
plt.xlabel('Department')
plt.show()

# %%
### Observations:
#✔ More number of Irregular employees are present in the  Department Production.---They can be Terminated.

# %%
df.plot(kind='scatter',x='Salary',y='Engagement_Survey')
plt.show()

# %%
### Observations:
✔ From this we can say that many people with high Engagement score are getting low salary.
✔ So company should provide additional benifits for these employees to encourage them.

# %%
plt.figure(figsize=(20,7))
sns.countplot(data=df,x='Department',hue='Performance_Score');

# %%
### Observations:
✔ From this we can know the department wise performance score.
✔ More number of talented employees are present in Production departent.

# %%
sns.set_theme()

# %%
plt.figure(figsize=(18,7))
plt.bar(df['Department'],df['Num_Spc_Projects'])
plt.xlabel('Department')
plt.ylabel('Num_Spc_Projects')
plt.show()

# %%
### Observations:
✔ More number of special projects are done in the IT department.
✔ So company can provide additional benifits for this employees.

# %%
lp=df[(df['Engagement_Survey']<3) & (df['Terminated']==0)]
lp
# Out:
#              Employee_Name  Salary  Terminated                  Position  \
# 23          Blount, Dianna   66441           0  Production Technician II
# 67           Delarge, Alex   61568           0        Area Sales Manager
# 69         Desimone, Carl    53189           0   Production Technician I
# 72       Dietrich, Jenna     59231           0        Area Sales Manager
# 79              Dunne, Amy   62514           0   Production Technician I
# 90     Fernandes, Nilson     64057           0   Production Technician I
# 91              Fett, Boba   53366           0          Network Engineer
# 190          Monroe, Peter  157000           0        IT Manager - Infra
# 246  Saar-Beckles, Melinda   47750           0   Production Technician I
# 258            Smith, John   72992           0             Sales Manager
# 263       Sparks, Taylor     64021           0   Production Technician I
# 267     Stansfield, Norman   58273           0        Area Sales Manager
# 283             Trang, Mei   63025           0   Production Technician I
# 288        Valentin,Jackie   57859           0        Area Sales Manager
#
#            DOB Gender Marital_Status Hiring_Date Termination_Date  \
# 23  1990-09-21      F         Single  2011-04-04              NaT
# 67  1975-02-11     M          Single  2014-09-29              NaT
# 69  1967-04-19     M         Married  2014-07-07              NaT
# 72  1987-05-14      F         Single  2012-02-20              NaT
# 79  1973-09-23      F        Married  2010-04-26              NaT
# 90  1989-10-18     M         Married  2015-11-05              NaT
# 91  1987-06-18     M          Single  2015-03-30              NaT
# 190 1986-05-10     M         Married  2012-02-15              NaT
# 246 1968-06-06      F         Single  2016-04-07              NaT
# 258 1984-08-16     M        Divorced  2014-05-18              NaT
# 263 1968-07-20      F        Married  2012-02-20              NaT
# 267 1974-09-05     M         Married  2014-12-05              NaT
# 283 1983-05-16      F         Single  2014-02-17              NaT
# 288 1991-05-23      F        Married  2011-05-07              NaT
#
#     Termination_Reason  ...     Manager_Name Manager_ID  Recruitment_Source  \
# 23   N/A-StillEmployed  ...   Michael Albert       22.0       CareerBuilder
# 67   N/A-StillEmployed  ...       John Smith       17.0              Indeed
# 69   N/A-StillEmployed  ...         Amy Dunn       11.0              Indeed
# 72   N/A-StillEmployed  ...       John Smith       17.0             Website
# 79   N/A-StillEmployed  ...    Ketsia Liebig       19.0       Google Search
# 90   N/A-StillEmployed  ...         Amy Dunn       11.0              Indeed
# 91   N/A-StillEmployed  ...     Peter Monroe        7.0            LinkedIn
# 190  N/A-StillEmployed  ...  Jennifer Zamora        5.0  Diversity Job Fair
# 246  N/A-StillEmployed  ...    Kelley Spirea       18.0  Diversity Job Fair
# 258  N/A-StillEmployed  ...   Debra Houlihan       15.0  Diversity Job Fair
# 263  N/A-StillEmployed  ...   Brannon Miller       12.0              Indeed
# 267  N/A-StillEmployed  ...    Lynn Daneault       21.0             Website
# 283  N/A-StillEmployed  ...    David Stanley       14.0            LinkedIn
# 288  N/A-StillEmployed  ...       John Smith       17.0              Indeed
#
#      Performance_Score Engagement_Survey Satisfaction_Score  Num_Spc_Projects  \
# 23   Needs Improvement              2.00                  3                 0
# 67                 PIP              1.93                  3                 0
# 69                 PIP              1.12                  2                 0
# 72                 PIP              2.30                  1                 0
# 79         Fully Meets              2.90                  3                 0
# 90                 PIP              1.56                  5                 0
# 91                 PIP              1.20                  3                 6
# 190  Needs Improvement              2.39                  3                 6
# 246  Needs Improvement              2.60                  4                 0
# 258  Needs Improvement              2.40                  4                 0
# 263                PIP              2.40                  2                 1
# 267                PIP              1.81                  2                 0
# 283  Needs Improvement              2.44                  5                 0
# 288        Fully Meets              2.81                  3                 0
#
#      Last_Perf_Review_Date  Dayslate30 Num_Absences
# 23              2019-02-27           2            3
# 67              2019-01-30           6            5
# 69              2019-01-31           4            9
# 72              2019-01-29           2           17
# 79              2019-01-21           0            6
# 90              2019-03-01           6           15
# 91              2019-04-02           3            2
# 190             2019-02-22           4           13
# 246             2019-02-18           5            4
# 258             2019-01-16           2           16
# 263             2019-02-25           6           20
# 267             2019-01-17           3            5
# 283             2019-11-02           4           18
# 288             2019-01-17           0           16
#
# [14 rows x 22 columns]

# %%
lp.groupby('Department').agg({'Engagement_Survey':'count'})
# Out:
#                    Engagement_Survey
# Department
# IT/IS                              2
# Production                         7
# Sales                              5

# %%
### Observations:
✔ Employees with less engagement score are present in the department Production
✔ People with low_engagement score(low performance) in which we can replace them talented freshers.

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=df,x='Performance_Score',hue='Terminated');

# %%
### Observations:
✔ Here most of the cases the persons with 'Fully meets' performance are Terminated---- company should make note of it .

# %%
plt.bar(df['Satisfaction_Score'],df['Engagement_Survey'])
plt.xlabel('Satisfaction_Score')
plt.ylabel('Engagement_Survey')
plt.show()

# %%
### Observations:
✔ People with low engagement score and low Satisfaction_Score are not needed for the company.

# %%
w_hire=df[df['Performance_Score'].isin(['PIP'] or df['Terminated']==0)] 
w_hire
# Out:
#            Employee_Name  Salary  Terminated                  Position  \
# 67         Delarge, Alex   61568           0        Area Sales Manager
# 69       Desimone, Carl    53189           0   Production Technician I
# 72     Dietrich, Jenna     59231           0        Area Sales Manager
# 83        Erilus, Angela   56847           0  Production Technician II
# 90   Fernandes, Nilson     64057           0   Production Technician I
# 91            Fett, Boba   53366           0          Network Engineer
# 95         Forrest, Alex   70187           1        Area Sales Manager
# 112       Gonzalez, Juan   68898           1  Production Technician II
# 188          Miller, Ned   55800           1  Production Technician II
# 205         O'hare, Lynn   52674           1   Production Technician I
# 263     Sparks, Taylor     64021           0   Production Technician I
# 267   Stansfield, Norman   58273           0        Area Sales Manager
# 307   Ybarra, Catherine    48513           1   Production Technician I
#
#            DOB Gender Marital_Status Hiring_Date Termination_Date  \
# 67  1975-02-11     M          Single  2014-09-29              NaT
# 69  1967-04-19     M         Married  2014-07-07              NaT
# 72  1987-05-14      F         Single  2012-02-20              NaT
# 83  1989-08-25      F      Separated  2014-07-07              NaT
# 90  1989-10-18     M         Married  2015-11-05              NaT
# 91  1987-06-18     M          Single  2015-03-30              NaT
# 95  1975-07-07     M         Married  2014-09-29       2018-08-19
# 112 1964-12-10     M         Married  2010-04-26       2011-05-30
# 188 1985-06-29     M          Single  2011-08-15       2014-04-09
# 205 1980-09-30      F         Single  2014-03-31       2018-01-05
# 263 1968-07-20      F        Married  2012-02-20              NaT
# 267 1974-09-05     M         Married  2014-12-05              NaT
# 307 1982-04-05      F         Single  2008-02-09       2015-09-29
#
#     Termination_Reason  ...    Manager_Name Manager_ID  Recruitment_Source  \
# 67   N/A-StillEmployed  ...      John Smith       17.0              Indeed
# 69   N/A-StillEmployed  ...        Amy Dunn       11.0              Indeed
# 72   N/A-StillEmployed  ...      John Smith       17.0             Website
# 83   N/A-StillEmployed  ...  Michael Albert       22.0              Indeed
# 90   N/A-StillEmployed  ...        Amy Dunn       11.0              Indeed
# 91   N/A-StillEmployed  ...    Peter Monroe        7.0            LinkedIn
# 95    Fatal attraction  ...   Lynn Daneault       21.0   Employee Referral
# 112      career change  ...  Brannon Miller       12.0  Diversity Job Fair
# 188            unhappy  ...  Brannon Miller       12.0            LinkedIn
# 205        performance  ...  Kissy Sullivan       20.0            LinkedIn
# 263  N/A-StillEmployed  ...  Brannon Miller       12.0              Indeed
# 267  N/A-StillEmployed  ...   Lynn Daneault       21.0             Website
# 307   Another position  ...  Brannon Miller       12.0       Google Search
#
#      Performance_Score Engagement_Survey Satisfaction_Score  Num_Spc_Projects  \
# 67                 PIP              1.93                  3                 0
# 69                 PIP              1.12                  2                 0
# 72                 PIP              2.30                  1                 0
# 83                 PIP              3.00                  1                 0
# 90                 PIP              1.56                  5                 0
# 91                 PIP              1.20                  3                 6
# 95                 PIP              2.00                  5                 0
# 112                PIP              3.00                  3                 0
# 188                PIP              3.00                  2                 0
# 205                PIP              2.33                  2                 0
# 263                PIP              2.40                  2                 1
# 267                PIP              1.81                  2                 0
# 307                PIP              3.20                  2                 0
#
#      Last_Perf_Review_Date  Dayslate30 Num_Absences
# 67              2019-01-30           6            5
# 69              2019-01-31           4            9
# 72              2019-01-29           2           17
# 83              2019-02-25           2            5
# 90              2019-03-01           6           15
# 91              2019-04-02           3            2
# 95              2019-01-28           4            7
# 112             2011-06-03           3           10
# 188             2013-01-14           6            6
# 205             2018-09-03           6            3
# 263             2019-02-25           6           20
# 267             2019-01-17           3            5
# 307             2015-02-09           5            4
#
# [13 rows x 22 columns]

# %%
### Observations:
✔ The company does not need this employees.So wrong Hiring is done in the company ----------Future Risk identified.

# %%
p=pd.crosstab(df['Recruitment_Source'],df['Performance_Score'])
p.sort_values('Fully Meets',ascending=False)
# Out:
# Performance_Score        Exceeds  Fully Meets  Needs Improvement  PIP
# Recruitment_Source
# Indeed                        12           66                  4    5
# LinkedIn                       9           61                  3    3
# Google Search                  2           43                  3    1
# Employee Referral              5           25                  0    1
# Diversity Job Fair             6           18                  4    1
# CareerBuilder                  2           17                  4    0
# Website                        1           10                  0    2
# Other                          0            2                  0    0
# On-line Web application        0            1                  0    0

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df,x='Recruitment_Source',hue='Performance_Score');

# %%
### Observations:
#✔ More number of freshers are recruited through Source:Indeed,Linked-in  and with better performance.
#✔ In future, for correct Hiring the company can post job notification in these sources.
